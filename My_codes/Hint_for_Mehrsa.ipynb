# %% [markdown]
# How to easily read a csv file with a lot of rows

# %%
import numpy as np 
import pandas as pd

# %%
# %run ./DataGen2.ipynb

# %%
data = pd.read_csv('/Users/Eliana/Documents/PDM/2juin_aRanger/' + 'eliana_test_DData.csv')

# %%
print(len(data))
print(data.columns)
# Out:
# 97748
# Index(['id', 'frame', 'x', 'y', 'N_photons', 'sigma'], dtype='object')

# %%
plt.figure(figsize = (10,10))
plt.scatter(data['x'], data['y'], s= 0.001)
