# %%
# %run ./DataGen2.ipynb

# %% [markdown]
# ### GrapHiC's analysis of data being read from a csv file

# %%
sigma_s = 32.0

# %%
data = pd.read_csv('/Users/Eliana/Documents/PDM/example_standard.csv')

data = modify_cov_matrix_format(data) 

# compute_T_95 is the function that computes T
T = compute_T_95(N = len(data), ListOfCovMatrices = data['cov_matrix'], sigma_s = sigma_s)
labels = calling_graphic(data, sigma_s, T)
labels_clean = remove_small_clusters(labels, min_size = 5)

# %%
labels_clean
# Out:
# array([11., 11., 11., ...,  0.,  0.,  0.])

# %%
data
# Out:
#                 x            y  labels_1      sigma  N_photons  \
# 0     2295.228677  3093.061426         1  22.571414    15000.0
# 1     2347.000978  3134.762748         1  16.489787    15000.0
# 2     2331.593239  3103.488933         1  17.896367    15000.0
# 3     2313.204910  3075.608722         1  18.249455    15000.0
# 4     2342.649889  3082.306994         1  23.662307    15000.0
# ...           ...          ...       ...        ...        ...
# 1915  1417.895730  1643.513550         0  23.353120    15000.0
# 1916  1706.372608  2860.298633         0  18.458124    15000.0
# 1917   612.528504  3603.222505         0  21.797504    15000.0
# 1918  3400.569059  3337.309852         0  23.077165    15000.0
# 1919   449.977040  2835.083824         0  17.814556    15000.0
#
#                                              cov_matrix
# 0     [[509.4687218503971, 0.0], [0.0, 509.468721850...
# 1     [[271.9130840426748, 0.0], [0.0, 271.913084042...
# 2     [[320.27995740821746, 0.0], [0.0, 320.27995740...
# 3     [[333.0426173495472, 0.0], [0.0, 333.042617349...
# 4     [[559.904765678206, 0.0], [0.0, 559.9047656782...
# ...                                                 ...
# 1915  [[545.3682318305948, 0.0], [0.0, 545.368231830...
# 1916  [[340.70232407052396, 0.0], [0.0, 340.70232407...
# 1917  [[475.13118353631944, 0.0], [0.0, 475.13118353...
# 1918  [[532.5555367562991, 0.0], [0.0, 532.555536756...
# 1919  [[317.358397645434, 0.0], [0.0, 317.3583976454...
#
# [1920 rows x 6 columns]

# %% [markdown]
# ### GrapHiC's analysis of data directly generated

# %%
data['cov_matrix'].iloc[1]
# Out:
# array([[271.91308404,   0.        ],
#        [  0.        , 271.91308404]])

# %%
np.array(data2['cov_matrix'].iloc[1])
# Out:
# array([[321.58001173,   0.        ],
#        [  0.        , 321.58001173]])

# %%
len(data2)
# Out:
# 1920

# %%
p = Standard_Param()

data_generator = Call_DataGenerator(p)

data2 = data_generator.GetAllData()
data2 = modify_cov_matrix_format(data2) 

T2 = compute_T_95(N = len(data2), ListOfCovMatrices = data2['cov_matrix'], sigma_s = sigma_s)
labels2 = calling_graphic(data2, sigma_s, T2)
labels_clean2 = remove_small_clusters(labels2, min_size = 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-9054bb79cbbb> in <module>
#       4
#       5 data2 = data_generator.GetAllData()
# ----> 6 data2 = modify_cov_matrix_format(data2)
#       7
#       8 T2 = compute_T_95(N = len(data2), ListOfCovMatrices = data2['cov_matrix'], sigma_s = sigma_s)
#
# <ipython-input-29-e7228aae45ea> in modify_cov_matrix_format(data)
#       2     matrices = data['cov_matrix']
#       3     #if type((matrices).iloc[0]) == str:
# ----> 4     temp = [np.array(eval(matrix_in_string)) for matrix_in_string in matrices]
#       5     data['cov_matrix'] = temp
#       6
#
# <ipython-input-29-e7228aae45ea> in <listcomp>(.0)
#       2     matrices = data['cov_matrix']
#       3     #if type((matrices).iloc[0]) == str:
# ----> 4     temp = [np.array(eval(matrix_in_string)) for matrix_in_string in matrices]
#       5     data['cov_matrix'] = temp
#       6
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
data2 = data_generator.GetAllData()
data2
# Out:
#                 x            y  labels_1      sigma  N_photons  \
# 0     3657.961111  1965.153609         1  18.366182    15000.0
# 1     3662.738212  1972.586638         1  20.232471    15000.0
# 2     3675.678709  1940.040260         1  21.835380    15000.0
# 3     3650.270074  1972.235098         1  17.473601    15000.0
# 4     3659.145264  1957.388670         1  22.658294    15000.0
# ...           ...          ...       ...        ...        ...
# 1915   522.030607  1325.136456         0  21.660011    15000.0
# 1916   642.912905   835.233545         0  21.508082    15000.0
# 1917  2582.982083  3579.572316         0  17.792963    15000.0
# 1918   948.534722    20.253383         0  23.545300    15000.0
# 1919   383.768578   136.859963         0  23.780290    15000.0
#
#                                              cov_matrix
# 0      [[337.3166535708259, 0], [0, 337.3166535708259]]
# 1      [[409.3528681129542, 0], [0, 409.3528681129542]]
# 2      [[476.7838096401239, 0], [0, 476.7838096401239]]
# 3      [[305.3267456228061, 0], [0, 305.3267456228061]]
# 4        [[513.398288422606, 0], [0, 513.398288422606]]
# ...                                                 ...
# 1915  [[469.15607137279966, 0], [0, 469.156071372799...
# 1916   [[462.5975999920655, 0], [0, 462.5975999920655]]
# 1917   [[316.5895212502479, 0], [0, 316.5895212502479]]
# 1918   [[554.3811383314425, 0], [0, 554.3811383314425]]
# 1919   [[565.5021726332864, 0], [0, 565.5021726332864]]
#
# [1920 rows x 6 columns]
